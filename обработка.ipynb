# %%
import numpy as np
import pandas as pd
from scipy.stats import mode

import matplotlib
import matplotlib.image as img
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
DATASET_PATH = 'C:/Users/GrIg2/Desktop/учебный/pandas_matnolib/дз/курсовая/train.csv'

# %%
df = pd.read_csv(DATASET_PATH, sep=',')
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
mode(df['HouseFloor'])
# Out:
# ModeResult(mode=array([17.]), count=array([2331]))

# %%
df.isna().sum() #пропуски
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %%
median = df['LifeSquare'].median() 
df['LifeSquare'].fillna(median, inplace=True) #заменил пропуски на медиану
median = df['Healthcare_1'].median() 
df['Healthcare_1'].fillna(median, inplace=True)

# %%
df.isna().sum() #проверка пропусков
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# dtype: int64

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     36.266040
# std     4859.01902     43.587592      0.839512     21.058732     76.609981
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     25.527399
# 50%     8394.50000     36.000000      2.000000     52.513310     32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625     41.427234
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
df.loc[df['Rooms']==0, 'Rooms'] = df['Rooms'].median() #заменил все 0 комнат на медиану (2)

# %%
room = df[(df['Rooms'] >5)]
room
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2004   5927          57   10.0  59.056975   36.223072           10.0     22
# 2728  14865           9   10.0  60.871266   38.420681           10.0      3
# 6088   8491           1   19.0  42.006046   21.779288            7.0     17
# 8794  14003          99    6.0  59.414334   38.702244            6.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2004        22.0       2002   0.090799         B         B        74
# 2728         2.0       1994   0.161532         B         B        25
# 6088        17.0       2014   0.007122         B         B         1
# 8794         9.0       1969   0.033494         B         B        66
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2004     19083         2         900.0            5       15       B
# 2728      5648         1          30.0            2        4       B
# ...

# %%
df.loc[df['Rooms']>5, 'Rooms'] = df['Rooms'].median()

# %%
room = df[(df['Rooms'] >4)]
room
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 403   13434          13    5.0  183.382273  100.985505           15.0      2
# 505    3454           8    5.0  112.135525   79.795451           10.0      4
# 511    8685          62    5.0  124.933289   81.122369           30.0      5
# 940    4971         169    5.0  117.855969   76.561318            9.0     12
# 1459   8901          34    5.0  121.577423  114.913843            1.0     25
# 1906   5548          86    5.0  275.645284  233.949309           26.0     12
# 1909    238          88    5.0   90.762276   70.991790            5.0      1
# 2516    338          46    5.0  147.709302   32.781260            0.0      6
# 2799   6358          27    5.0   42.003293   32.781260            0.0      5
# 5665   1243          86    5.0  108.057398   82.723825            8.0      3
# 5737   3294         167    5.0  111.045799   81.940459            9.0      6
# ...

# %%
df.loc[(df['Square'] < 80) | (df['Rooms']>4, 'Rooms')] = df['Rooms'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anc\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ad80a042b5bd> in <module>
# ----> 1 df.loc[(df['Square'] < 80) | (df['Rooms']>4, 'Rooms')] = df['Rooms'].median()
#
# D:\anc\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
# ...

# %%
room = df[(df['Rooms'] >4)]
room

# %%
df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %%
plt.figure(figsize = (16, 8))

plt.subplot(121)
df['Price'].hist(density=False, bins=20)
plt.ylabel('count')
plt.xlabel('Price')

plt.subplot(122)
sns.kdeplot(df['Price'], shade=True, legend=False)
plt.xlabel('Price')

plt.suptitle('Distribution of median_house_value')
plt.show()

# %%
target_mean = round(df['Price'].mean(), 2)
target_median = df['Price'].median()
target_mode = df['Price'].mode()[0]

plt.figure(figsize = (16, 8))

sns.distplot(df['Price'], bins=50)

y = np.linspace(0, 0.000005, 10)
plt.plot([target_mean] * 10, y, label='mean',  linewidth=4)
plt.plot([target_median] * 10, y, label='median',  linewidth=4)
plt.plot([target_mode] * 10, y, label='mode', linewidth=4)

plt.title('Distribution of Price')
plt.legend()
plt.show()

# %%
target_bins = df['Price']//10000*10000
target_adjusted_mode=target_bins.mode()[0]
target_adjusted_mode
#df['Price'].value_counts
# Out:
# 180000.0

# %%
target_bins.value_counts().iloc[:10]
# Out:
# 180000.0    740
# 170000.0    673
# 160000.0    614
# 190000.0    596
# 150000.0    543
# 200000.0    517
# 140000.0    495
# 210000.0    469
# 130000.0    435
# 220000.0    373
# Name: Price, dtype: int64

# %%
target_mean = round(target_bins.mean(), 2)
target_median = target_bins.median()
target_mode = target_bins.mode()[0]

plt.figure(figsize = (16, 8))

sns.distplot(df['Price'], bins=50)

y = np.linspace(0, 0.000005, 10)
plt.plot([target_mean] * 10, y, label='mean',  linewidth=4)
plt.plot([target_median] * 10, y, label='median',  linewidth=4)
plt.plot([target_mode] * 10, y, label='mode', linewidth=4)

plt.title('Distribution of Price')
plt.legend()
plt.show()

# %%
t1_num_features = df.select_dtypes(include=['int64', 'float64', 'float32', 'float16'])
t1_num_features.hist(figsize=(20,20), bins=10, grid=False);

# %%
Square = df[(df['Square'] >200)]
Square
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 726      28           9    2.0  604.705972   32.781260            1.0     17
# 1776  16568          27    4.0  200.334539  201.627361           25.0      1
# 1906   5548          86    5.0  275.645284  233.949309           26.0     12
# 7010   2307         102    1.0  409.425181  410.639749           10.0      4
# 7644   7917          27    2.0  212.932361  211.231125            0.0      2
# 9229  11602          30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 726         18.0       1977   0.161532         B         B        25
# 1776         2.0       2013   0.041116         B         B        53
# 1906        37.0       2011   0.161976         B         A        31
# 7010         4.0       2016   0.238617         B         B        26
# 7644         3.0       2008   0.211401         B         B         9
# ...

# %%
SquareDiff = df[(df['Square'] < df['LifeSquare'])]
SquareDiff
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 33      847          74    2.0  73.314975   74.131261            1.0      7
# 64     3992           1    3.0  87.200625   87.730225            0.0     21
# 77    11771          45    1.0  38.467276   39.624493            1.0     11
# 100   13343          74    2.0  79.937665   82.931595            1.0      8
# 111   13875          20    1.0  28.438794   32.514021            6.0      6
# ...     ...         ...    ...        ...         ...            ...    ...
# 9960  16258          48    3.0  96.056784   98.152802            1.0     15
# 9962  14175          14    1.0  42.029175   44.682167           10.0      4
# 9979   2201           6    1.0  40.043234   41.984322            1.0      3
# 9987  11665           1    2.0  62.690057   64.602939           10.0     19
# 9993   9289           1    3.0  84.486078   88.931509            0.0      4
#
# ...

# %%
df.loc[df['Square'] < df['LifeSquare']] = df.rename(columns={"Square": "LifeSquare", "LifeSquare": "Square"})

#for i in df:
#    if (df['Square'] < df['LifeSquare']):
#        df.rename(columns={"Square": "LifeSquare", "LifeSquare": "Square"})

# %%
SquareDiff = df[(df['Square'] < df['LifeSquare'])]
SquareDiff
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
Square = df[(df['Square'] >200)]
Square
# Out:
#          Id  DistrictId  Rooms       Square  LifeSquare  KitchenSquare  Floor  \
# 357   14990          23    2.0   263.542020   48.449873            5.0      6
# 726      28           9    2.0   604.705972   32.781260            1.0     17
# 1776  16568          27    4.0   201.627361  200.334539           25.0      1
# 1906   5548          86    5.0   275.645284  233.949309           26.0     12
# 5183  15886          85    3.0   461.463614   78.059331           10.0     12
# 7010   2307         102    1.0   410.639749  409.425181           10.0      4
# 7644   7917          27    2.0   212.932361  211.231125            0.0      2
# 8000  16550          27    3.0  7480.592129   81.694417            1.0      9
# 9229  11602          30    2.0   641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 357          5.0       1972   0.075779         B         B         6
# ...

# %%
df = df.drop([357, 726, 1776, 5183, 7010, 9229])  #8000, 357, 726, 1776, 5183, 7010, 9229
Square = df[(df['Square'] >200)]
Square
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1906  5548          86    5.0  275.645284  233.949309           26.0     12
# 7644  7917          27    2.0  212.932361  211.231125            0.0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1906        37.0       2011   0.161976         B         A        31
# 7644         3.0       2008   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1906      7010         5        4508.0            3        7       B
# 7644      1892         0         900.0            0        1       B
#
#               Price
# 1906  455264.882666
# 7644  302211.260887

# %%
df.loc[df['HouseFloor'] < df['Floor']] = df.rename(columns={"HouseFloor": "Floor", "Floor": "HouseFloor"})

# %%
df.loc[df['Square'] - df['LifeSquare'] > 50, 'Square'] = df['Square'].median()

# %%
KitchenSquare = df[((df['HouseYear'] > 1900))]
KitchenSquare
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  52.509275   32.781260           10.0    4.0
# 1      3013          22    1.0  39.832524   23.169223            8.0    7.0
# 2      8215           1    3.0  78.342215   47.671972           10.0    2.0
# 3      2352           1    1.0  40.409907   32.781260            1.0   10.0
# 4     13866          94    2.0  64.285067   38.562517            9.0   16.0
# ...     ...         ...    ...        ...         ...            ...    ...
# 9995   1260          61    2.0  49.090728   33.272626            6.0    3.0
# 9996  16265          27    2.0  64.307684   37.038420            9.0    0.0
# 9997   2795         178    1.0  29.648057   16.555363            5.0    3.0
# 9998  14561          21    1.0  32.330292   22.326870            5.0    3.0
# 9999   7202          94    1.0  35.815476   22.301367            6.0    9.0
#
# ...

# %%
df = df.drop([286, 682, 1728, 2454, 2785, 2831, 3240, 3586, 3725, 3956, 5002,
              5273, 5663, 5792, 6293, 6505, 7080, 7601, 7733, 8329, 9520]) #повторения и выбивающиеся из нормы данные

# %%
df = df.drop([8855, 8011, 5033, 4091, 2790, 2702, 2632, 2325, 2108, 1614, 456])

# %%
df.loc[(df['KitchenSquare'] > 50)] = df['KitchenSquare'].median()

# %%
df = pd.concat([df, pd.get_dummies(df['Ecology_3'])], axis=1)
df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  11809          27    3.0  52.509275   32.781260           10.0    4.0
# 1   3013          22    1.0  39.832524   23.169223            8.0    7.0
# 2   8215           1    3.0  78.342215   47.671972           10.0    2.0
# 3   2352           1    1.0  40.409907   32.781260            1.0   10.0
# 4  13866          94    2.0  64.285067   38.562517            9.0   16.0
#
#    HouseFloor  HouseYear  Ecology_1  ... Social_3 Healthcare_1  Helthcare_2  \
# 0        10.0       2014   0.075424  ...        0        900.0            0
# 1         8.0       1966   0.118537  ...        1       1183.0            1
# 2        17.0       1988   0.025609  ...        0        240.0            3
# 3        22.0       1977   0.007122  ...        0        900.0            0
# 4        16.0       1972   0.282798  ...        2        900.0            0
#
#    Shops_1  Shops_2          Price  A  B  A  B
# ...

# %%
t1_num_features = df.select_dtypes(include=['int64', 'float64', 'float32', 'float16'])
t1_num_features.hist(figsize=(20,20), bins=10, grid=False);

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9961.000000  9961.000000  9961.000000  9961.000000  9961.000000
# mean    8380.326272    50.404176     1.887662    54.579178    35.163247
# std     4854.973566    43.615183     0.810529    16.710555    15.489637
# min        0.000000     0.000000     1.000000     2.377248     0.370619
# 25%     4171.000000    20.000000     1.000000    41.857859    25.488760
# 50%     8393.000000    36.000000     2.000000    52.509275    32.781260
# 75%    12586.000000    75.000000     2.000000    64.082751    41.030459
# max    16798.000000   209.000000     5.000000   275.645284   233.949309
#
#        KitchenSquare        Floor   HouseFloor     HouseYear    Ecology_1  \
# count    9961.000000  9961.000000  9961.000000  9.961000e+03  9961.000000
# mean        5.695282     7.697721    13.406686  3.997932e+03     0.118916
# std         3.938610     5.299227     5.871478  2.008924e+05     0.119038
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  52.509275   32.781260           10.0    4.0
# 1      3013          22    1.0  39.832524   23.169223            8.0    7.0
# 2      8215           1    3.0  78.342215   47.671972           10.0    2.0
# 3      2352           1    1.0  40.409907   32.781260            1.0   10.0
# 4     13866          94    2.0  64.285067   38.562517            9.0   16.0
# ...     ...         ...    ...        ...         ...            ...    ...
# 9995   1260          61    2.0  49.090728   33.272626            6.0    3.0
# 9996  16265          27    2.0  64.307684   37.038420            9.0    0.0
# 9997   2795         178    1.0  29.648057   16.555363            5.0    3.0
# 9998  14561          21    1.0  32.330292   22.326870            5.0    3.0
# 9999   7202          94    1.0  35.815476   22.301367            6.0    9.0
#
# ...

# %%
df = df.drop(columns=["Ecology_2", "Ecology_3", 'Shops_2'], axis = 1)

# %%
#df = pd.concat([df, pd.get_dummies(df['Ecology_2'])], axis=1)
df = df.rename(columns={"A": "Ecology_2_A", "B": "Ecology_2_B"})

# %%
df = pd.concat([df, pd.get_dummies(df['Ecology_3'])], axis=1)
df = df.rename(columns={"A": "Ecology_3_A", "B": "Ecology_3_B"})

# %%
df = pd.concat([df, pd.get_dummies(df['Shops_2'])], axis=1)
df = df.rename(columns={"A": "Shops_2_A", "B": "Shops_2_B"})

# %%
df.to_csv('исход.csv')
